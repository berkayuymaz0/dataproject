# %%
df_renewable_power_generationcopy = df_renewable_power_generation.copy()

years_by_five = np.arange(1990, 2017, 5).tolist()
df_renewable_power_generationcopy_six = df_renewable_power_generationcopy[df_renewable_power_generationcopy['Year'].isin(years_by_five)]

display(df_renewable_power_generationcopy_six)

colors = ["crimson", "darkorange", "darkmagenta", "darkgreen"]

figure, axis = plt.subplots(3, 2, figsize=(15,25))
figure.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", pad=40, bottom=False, left=False,grid_color='none')

df_renewable_power_generationcopy_six = df_renewable_power_generationcopy_six.drop('Year', axis=1)

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[0]], ax=axis[0, 0], palette=colors)
axis[0, 0].set(ylim=(0, 4250))
axis[0, 0].set_title("1990")

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[1]], ax=axis[0, 1], palette=colors)
axis[0, 1].set(ylim=(0, 4250))
axis[0, 1].set_title("1995")

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[2]], ax=axis[1, 0], palette=colors)
axis[1, 0].set(ylim=(0, 4250))
axis[1, 0].set_title("2000")

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[3]], ax=axis[1, 1], palette=colors)
axis[1, 1].set(ylim=(0, 4250))
axis[1, 1].set_title("2005")

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[4]], ax=axis[2, 0], palette=colors)
axis[2, 0].set(ylim=(0, 4250))
axis[2, 0].set_title("2010")

sn.barplot(data=df_renewable_power_generationcopy_six.iloc[[5]], ax=axis[2, 1], palette=colors)
axis[2, 1].set(ylim=(0, 4250))
axis[2, 1].set_title("2015")

plt.title("Disturbution of Renewable Energy Generation Through Years\n\n")
plt.show()
# Out:
#     Year  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)
# 0   1990     2191.67          3.88            0.09             36.42
# 5   1995     2545.96          7.95            0.19             39.89
# 10  2000     2695.85         31.34            0.99             51.98
# 15  2005     3019.50        103.92            3.92             58.28
# 20  2010     3530.72        341.38           32.22             68.10
# 25  2015     3989.28        838.31          250.75             80.56

# %%
df_renewable_power_generation_top20_copy = df_renewable_power_generation_top20.copy()
display(df_renewable_power_generation_top20_copy)

my_range=range(1,len(df_renewable_power_generation_top20_copy.index)+1)

plt.hlines(y=my_range, xmin=0, xmax=df_renewable_power_generation_top20_copy['Total (TWh)'], color='skyblue')
plt.yticks( my_range, df_renewable_power_generation_top20_copy['Country'])
plt.title("Total Renewable Energy Production in Top 20 Countries", loc='left')
plt.xlabel('Total (TWh)')
plt.ylabel('Country')
plt.plot(df_renewable_power_generation_top20_copy['Total (TWh)'], my_range, "o")
plt.show()
# Out:
#         Country  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)  \
# 0         China     1189.84      295.0200           79.43            0.1250
# 1           USA      315.62      277.9100           58.95           18.9600
# 2        Brazil      370.90       42.3700           52.25            0.0000
# 3        Canada      383.48       29.6500            7.12            0.0000
# 4         India      141.80       51.0600           43.76            0.0000
# 5       Germany       24.17      111.5900           45.10            0.1600
# 6        Russia      187.13        0.1400            0.08            0.4300
# 7         Japan       90.67        7.6300           19.01            2.4400
# 8        France       70.13       28.5000            5.87            0.1300
# 9         Italy       50.92       17.4900           16.85            6.0800
# 10           UK        7.96       57.1100           32.08            0.0000
# ...
